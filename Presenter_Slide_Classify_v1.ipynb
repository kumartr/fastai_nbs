# %% [markdown]
# ## Build an image classifier with nothing but keywords

# %% [markdown]
# This is a fun little notebook that uses the [google-images-download](https://github.com/hardikvasa/google-images-download) python tool and the [fast.ai](https://github.com/fastai/fastai) pytorch library to create image classifiers by just using keywords. In this case we'll add Corn Dogs to the famous [Hot-Dog-Or-No-Hot-Dog Classifier](https://www.youtube.com/watch?v=ACmydtFDTGs). We'll do that by just specifying the classes 'Hot Dog' and 'Corn Dog', automatically download as much pictures as you want per class from google and fine tune the softmax layer of a ResNet34 model trained on ImageNet.

# %% [markdown]
# ## Prerequesites

# %% [markdown]
# ### Make sure you have pytorch and the fast.ai library installed and import the following:

# %%
from fastai import *
from fastai.vision import *
import PIL

# %% [markdown]
# ### Install the downloadtool and the dependencies

# %% [markdown]
# Here we'll install the tools needed to download pictures from google. You might have to add sudo rights to some commands (I'm inside a container and root). First the Python download tool:

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/18/ed/0319d30c48f3653802da8e6dcfefcea6370157d10d566ef6807cceb5ec4d/google_images_download-2.8.0.tar.gz
# Collecting selenium (from google_images_download)
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 5.1MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium->google_images_download) (1.24.3)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14550 sha256=bad4079e7ad786bfa43d607bd765617d3953c4f97518fd56f65832f67c7f4784
#   Stored in directory: /root/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.8.0 selenium-3.141.0

# %% [markdown]
# ## Get the pics with keywords

# %% [markdown]
# import the tool

# %%
from google_images_download import google_images_download

# %% [markdown]
# Set Path, image size and number of images to be downloaded. To download more than 100 images you have to install the chrome-driver (you'll find instructions at the bottom of the notebook).

# %%
PATH = "/fastai/data/FramePresenternSlides/"
nof_pics = 100

# %% [markdown]
# First we'll instantiate the downloader class. The dictionary `arguments` holds our classes as keywords, the number of files we want per class and the directory where the pics should be saved. If you want to download more than 100 images per class you have to install chrome-driver. When you paste in more keywords more classes will be created Adapt that to your needs!

# %%
response = google_images_download.googleimagesdownload()

arguments = {"keywords":"Frame Video Presenter,frame video ppt slides",
             "limit":nof_pics,
             "print_urls":False,
             "output_directory":f'{PATH}train',
             "chromedriver":"/usr/bin/chromedriver"}

paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Frame Video Presenter
# Evaluating...
# Starting Download...
# Completed Image ====> 1.17.png
# Completed Image ====> 2.fbi-agent-keith-scott-video1.jpg
# Completed Image ====> 3.screen-0.jpg
# Completed Image ====> 4.2r2kh0f5lup21.jpg
# Completed Image ====> 5.The-Preview-view-shows-the-frame-at-the-cursor-the-dotted-lines-in-Figure-5-and-is.png
# Completed Image ====> 6.5c6b2937a4d81.jpg
# Completed Image ====> 7.Camtasia-powerpoint-add-in-toolbar.jpg
# Completed Image ====> 8.Sample-video-frame-of-size-512-288-left.png
# Completed Image ====> 9.Client-Cetnricity-video-frame.png
# Completed Image ====> 10.702964387_780x439.jpg
# Completed Image ====> 11.hqdefault.jpg
# Completed Image ====> 12.hqdefault.jpg
# Completed Image ====> 13.2376.hazcomlessonv97tgq.png
# Completed Image ====> 14.Attacked-frames-of-Akiyo-a-Frame-dropping-Link-to-download-video-after-attack-b.png
# URLError on an image...trying next one... Error: HTTP Error 403: Forbidden
# Completed Image ====> 15.video-frame.png
# Completed Image ====> 16.maxresdefault.jpg
# Completed Image ====> 17.2-Figure1-1.png
# Completed Image ====> 18.recent-projects.png
# Completed Image ====> 19.1-12.jpeg
# Completed Image ====> 20.mp_442402_0_0jpg.jpg
# Completed Image ====> 21.The-First-Frame-Of-The-Three-Forman-Akiyo-Mohand-Tested-Videos.png
# Completed Image ====> 22.maxresdefault.jpg
# Completed Image ====> 23.DykH0VmUYAEN1Vi.jpg
# Completed Image ====> 24.frames.png
# Completed Image ====> 25.Video-Frame.png
# Completed Image ====> 26.frame-of-mind-video-mindyourselfy.jpg
# URLError on an image...trying next one... Error: HTTP Error 429: Too Many Requests
# Invalid or missing image format. Skipping...
# Completed Image ====> 27.CelebratingSuccess-5b7479dc46e0fb00503a065a-4ddd43e907c94dc7a079123846921d0f.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 28.782072440_780x439.jpg
# Completed Image ====> 29.f-uighurvid-a-20190214-870x522.jpg
# Completed Image ====> 30.image_2.png
# Completed Image ====> 31.AvivXYSCMAE2xip.jpg
# Completed Image ====> 32.bike-guy-replace-frame_764x430_Splash.jpg
# Completed Image ====> 33.screen-4.jpg
# Completed Image ====> 34.Moments-Frame-Slideshow-161553.jpg
# Completed Image ====> 35.850238b4af8b9dbb001bd435686e56f3.jpg
# Completed Image ====> 36.inline_image_preview.jpg
# URLError on an image...trying next one... Error: HTTP Error 503: Service Temporarily Unavailable
# Completed Image ====> 37.239034ce42de69c5e5b1dfb5e57649be63cd92f5.webp
# Completed Image ====> 38.Video3-Frame.jpg
# Completed Image ====> 39.ds_07005_04_nws_v6.jpg
# URLError on an image...trying next one... Error: <urlopen error unknown url type: x-raw-image>
# Completed Image ====> 40.9f2d75afbbf8da9d95582be0f5527703.jpg
# Completed Image ====> 41.43a9a9610ef14f025fbdfe6e8e59bb31.jpg
# Completed Image ====> 42.Music-Vid-American-Gothic-Screen-shots3-1dofmyk.jpg
# Completed Image ====> 43.Scene_-_Alex_2_Frame.png
# Completed Image ====> 44.TJJI6EBJI4I6RN456PMTDW37NA.jpg
# Completed Image ====> 45.shtlm43y1qx21.jpg
# Completed Image ====> 46.image_5d424b59c33c5b0013c39601_587426.jpg
# Completed Image ====> 47.DsIXsHpU0AENGJX.jpg
# Completed Image ====> 48.WLOXintvw-Frame.jpg
# Completed Image ====> 49.BBC-touchcast.jpg
# Completed Image ====> 50.OFF_P.jpg
# Completed Image ====> 51.295312139.jpg
# Completed Image ====> 52.tv-kid-tantrum-759.jpg
# Completed Image ====> 53.e320b87ef22a5409859025efa253461837f695f2.jpg
# Completed Image ====> 54.Diginex_02.jpg
# Completed Image ====> 55.Use-neon-colors-creative-presentation-ideas.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 56.bf71dd6b-ec79-4e1b-82d8-9aa9097b643c.png
# Completed Image ====> 57.mp_414388_0_0.jpg
# Completed Image ====> 58.81aa92b1e2ea42bd0d80c54bc49b92e9_original.jpg
# Completed Image ====> 59.choose-specific-frame.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 60.12548937_429763207221532_5299717018100901117_n-6.jpg
# Completed Image ====> 61.190417191939-ebof-john-dean-iso-large-169.jpg
# Completed Image ====> 62.screen-0.jpg
# Completed Image ====> 63.publish_advanced.jpg
# Completed Image ====> 64.190405_wnn_phelps_pic_hpMain_16x9_992.jpg
# Completed Image ====> 65.MV5BYjA4NmE5NGMtMWU4YS00ZjA0LWEwNzEtMjM5N2IxMGY2MGI1XkEyXkFqcGdeQXVyNTI5NjIyMw@@._V1_.jpg
# Completed Image ====> 66.n3jwy-cat-enters-streamers-camera-frame-funny-lg.jpg
# Completed Image ====> 67.101321a190d243d883a87689e4ea78f4ffc23c02.webp
# Completed Image ====> 68.03Jun13_Anderson_killer-presentation.png
# Completed Image ====> 69.120487.jpg
# Completed Image ====> 70.maxresdefault.jpg
# Completed Image ====> 71.5d27656641a92-1562862951.jpg
# Completed Image ====> 72.Fire-TV-Using-23.976-Refresh-Rate.jpg
# Completed Image ====> 73.MNBC-CH-XXXXXXXX_CLN_SDO-3A2_20_00_ALL_IN_with_CHRIS_HAYES_AS_frame_74983.jpg
# Completed Image ====> 74.00000003_2.jpg
# Completed Image ====> 75.best-mac-video-editors-main2_thumb800.png
# Completed Image ====> 76.BeckAV_Image07.jpg
# Completed Image ====> 77.Fox11-Video-Frame.png
# Completed Image ====> 78.video-presentation-recording-software-1280x969.png
# Completed Image ====> 79.en_paris_direct29_01_2019_07_59_30_frame_61722.jpg
# Completed Image ====> 80.Ashley_crop_noHeader_700.jpg
# Completed Image ====> 81.Snapshot-of-Akiyo-video-frame-number-140.png
# Invalid or missing image format. Skipping...
# Completed Image ====> 82.KNJHX2HOBYYCZCPLGYGOZ2G7W4.jpg
# Completed Image ====> 83.9201711538795206596.jpg
# Completed Image ====> 84.619590670_780x439.jpg
# Completed Image ====> 85.Thumbnailed-progress-bar-in-PotPlayer.jpg
# Completed Image ====> 86.1d1b803d5bc1fcfb7ef1788e3c4dc983.jpg
# Completed Image ====> 87.4769942_112618-wls-iteam-giving-quick-tip-vid.jpg
# Completed Image ====> 88.PHOTO-OF-THE-WEEK-FRAME-steve-essig2.jpg
# Completed Image ====> 89.150826USShooting01.jpg
# Completed Image ====> 90.when-you-use-a-different-frame-so-technically-this-meme-57960742.png
# Completed Image ====> 91._100429109_salmondrt-cbis303.1_frame_40766.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 91 is all we got for this search filter!
#
# Errors: 9
#
#
# Item no.: 2 --> Item name = frame video ppt slides
# Evaluating...
# Starting Download...
# Completed Image ====> 1.29a849e3-c3ab-48dc-adca-6b673a232d45.png
# Completed Image ====> 2.EmbedVideoPowerPoint-1-1280x666.90017513135-c-default.jpg
# Completed Image ====> 3.EmbedVideoPowerPoint-3-1280x635.6462585034-c-default.jpg
# Completed Image ====> 4.Change-TV-frame.png
# Completed Image ====> 5.EmbedVideoPowerPoint-4-1280x723.37614678899-c-default.jpg
# Completed Image ====> 6.Screen-Shot-2016-12-06-at-3.28.33-PM.png
# Completed Image ====> 7.3b7fdc38-e015-4a6f-b3f0-1779418c7ef9.jpg
# Completed Image ====> 8.Retro-TV-frame.png
# Completed Image ====> 9.Adding-movie-to-PPT-880x574.jpg
# Completed Image ====> 10.e087e484-ea9d-43ab-b011-c0c80d58802b.png
# Completed Image ====> 11.Add-video-to-TV-frame.png
# Completed Image ====> 12.aid1507535-v4-728px-Add-a-Video-to-Powerpoint-on-a-Mac-Step-6-Version-2.jpg
# Completed Image ====> 13.maxresdefault.jpg
# Completed Image ====> 14.maxresdefault.jpg
# Completed Image ====> 15.EmbedVideoPowerPoint-5-1280x748.58283433134-c-default.jpg
# Completed Image ====> 16.df4995c1-ecf0-44b4-ade8-bb44a5ee062c.png
# Completed Image ====> 17.how-to-add-video-to-powerpoint.png
# Completed Image ====> 18.aid553082-v4-728px-Make-a-Basic-Animated-Video-in-PowerPoint-Step-3-Version-2.jpg
# Completed Image ====> 19.powerpoint_tips_photo_album-1.png
# Completed Image ====> 20.powerpoint-add-video-582x322.png
# Completed Image ====> 21.vidcorrections2010-01.jpg
# Completed Image ====> 22.vid_insert_video_dialog.png
# Completed Image ====> 23.static_presentation_into-a_video-cover_2048x1024-2000x1000-2000x1000.jpg
# Completed Image ====> 24.how-to-insert-youtube-video-into-powerpoint.jpg
# Completed Image ====> 25.aid553082-v4-728px-Make-a-Basic-Animated-Video-in-PowerPoint-Step-1-Version-2.jpg
# Completed Image ====> 26.Embed-Video-PowerPoint-SM-1200x630-c-center.jpg
# Completed Image ====> 27.pptvid-mac-insert-menu.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 28.resizerotateflipvid2016-01.png
# Completed Image ====> 29.2-ways-to-add-a-video-in-powerpoint.png
# Completed Image ====> 30.001.png
# Completed Image ====> 31.Camtasia-powerpoint-add-in-toolbar.jpg
# Completed Image ====> 32.pptvid-trim-video.jpg
# Completed Image ====> 33.lIxDK3397S.gif
# Completed Image ====> 34.videos-PowerPoint-2.png
# Completed Image ====> 35.006.png
# Completed Image ====> 36.videos_poster_ribbon.png
# Completed Image ====> 37.Embed-Video-PowerPoint-S-1280x995.55555555556-c-default.jpg
# Completed Image ====> 38.screenshot-shapes-728_121321.jpg
# Completed Image ====> 39.VimeoHyperlink.png
# Completed Image ====> 40.Google-Slides-Video-Options.jpg
# Completed Image ====> 41.create-an-ultra-hd-4k-video-in-powerpoint-365.gif
# Completed Image ====> 42.maxresdefault.jpg
# Completed Image ====> 43.1-Blank-PPT-1024x787.png
# Invalid or missing image format. Skipping...
# Completed Image ====> 44.1*X0QNbf-S-E8z1lyAUWmJHw.png
# Completed Image ====> 45.005.png
# Completed Image ====> 46.CelebratingSuccess-5b7479dc46e0fb00503a065a-4ddd43e907c94dc7a079123846921d0f.jpg
# Completed Image ====> 47.maxresdefault.jpg
# Completed Image ====> 48.stock-lede-microsoft-office-powerpoint-6.png
# Completed Image ====> 49.add-video-to-Keynote-880x506.jpg
# Completed Image ====> 50.101321a190d243d883a87689e4ea78f4ffc23c02.webp
# Completed Image ====> 51.Capture-5c4dfa57c9e77c0001f3227e.JPG
# Completed Image ====> 52.494105-637032925282709175-16x9.jpg
# Completed Image ====> 53.Embed-Video-in-PowerPoint-Step-31.jpg
# Completed Image ====> 54.word-image-138.png
# Completed Image ====> 55.resizerotateflipvid2016-04.png
# Completed Image ====> 56.video_poster_command.png
# Completed Image ====> 57.4a3dce3d-bb05-49ae-85fd-59851438bcd0.jpg
# Completed Image ====> 58.how-a-pdf-ppt-to-video-work.gif
# Completed Image ====> 59.004.png
# Completed Image ====> 60.ppt2video01.png
# Completed Image ====> 61.powerpoint-to-video-converter-pro-l.jpg
# Completed Image ====> 62.ppttovideo_screenshot_3.png
# Completed Image ====> 63.maxresdefault.jpg
# Completed Image ====> 64.ngcb1.png
# Completed Image ====> 65.edit-music-sound-or-other-audio-settings-in-powerpoint-2-5c60369046e0fb0001442283.jpg
# Completed Image ====> 66.screencastomatic_recorder.png
# Completed Image ====> 67.ngcb1.jpg
# Completed Image ====> 68.screencastomatic_start.png
# Completed Image ====> 69.how-to-embed-a-youtube-video-in-powerpoint2-874x587.jpg
# Completed Image ====> 70.file.png
# Completed Image ====> 71.how-to-convert-a-powerpoint-presentation-to-a-pdf-file-6.jpg
# Completed Image ====> 72.add-video-file-powerpoint-582x333.png
# Completed Image ====> 73.3.jpg
# Completed Image ====> 74.how-to-embed-edit-youtube-video-in-powerpoint-2013-6-638.jpg
# Completed Image ====> 75.Screenshot-of-PowerPoint-Add-in-Toolbar-Menu-Options.jpg
# Completed Image ====> 76.ppt-to-video.png
# Completed Image ====> 77.b5e812a7-61ec-4005-84f4-dfcd76a53619.png
# Completed Image ====> 78.video-frame.png
# Completed Image ====> 79.blog-7-17-2018-changethesizeofslidesinpowerpoint.png
# Completed Image ====> 80.ppt-to-video-with-sound.gif
# Completed Image ====> 81.maxresdefault.jpg
# Completed Image ====> 82.microsoft_powerpoint_logo_primary-100567251-large.jpg
# Completed Image ====> 83.video-conferencing-within-a-frame-of-innovative-learning-infrastructures-n.jpg
# Completed Image ====> 84.ppt-to-video-online.jpg
# Completed Image ====> 85.aid553082-v4-728px-Make-a-Basic-Animated-Video-in-PowerPoint-Step-4-Version-2.jpg
# Completed Image ====> 86.BLOG_2016-images_key-26-880x492.jpg
# Completed Image ====> 87.top.jpg
# Completed Image ====> 88.How-to-embed-video-in-powerpoint-step1.gif
# Completed Image ====> 89.powerpoint-timeline-template.png
# Completed Image ====> 90.7136e228-8074-4df4-9f4e-611819f75f66.png
# Completed Image ====> 91.maxresdefault.jpg
# Completed Image ====> 92.87813708.jpg
# Completed Image ====> 93.slide1-n.jpg
# Completed Image ====> 94.b-googleslides-verticalslides.jpg
# Completed Image ====> 95.002.png
# Completed Image ====> 96.intro.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 97.maxresdefault.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 97 is all we got for this search filter!
#
# Errors: 3

# %% [markdown]
# ## Clean the data

# %% [markdown]
# I sometimes experienced, that corrupted pictures are downloaded. So let's check that and delete them:

# %%
def check_images(PATH):
    broken_images=[]
    for pic_class in os.listdir(PATH):
        for pic in os.listdir(f'{PATH}/{pic_class}'):
            try:
                img = PIL.Image.open(f'{PATH}/{pic_class}/{pic}') 
                img.verify()
            except (IOError, SyntaxError) as e:
                print('Bad file:', f'{PATH}/{pic_class}/{pic}')
                broken_images.append(f'{PATH}/{pic_class}/{pic}')
    return broken_images

# %%
img_to_del = check_images(f'{PATH}train')

# %%
[os.remove(pic) for pic in img_to_del]
# Out:
# [None, None, None, None]

# %% [markdown]
# ## Extract validation set

# %% [markdown]
# Now we need a little function to extract a validation set:

# %%
def make_val_set(PATH, nof_val_pics):
    if not os.path.exists(f'{PATH}valid'):
        os.makedirs(f'{PATH}valid')
        for pic_class in os.listdir(f'{PATH}train'):
            os.makedirs(f'{PATH}valid/{pic_class}')
            for pic in random.sample(os.listdir(f'{PATH}train/{pic_class}'), nof_val_pics):
                os.rename(f'{PATH}train/{pic_class}/{pic}', 
                          f'{PATH}valid/{pic_class}/{pic}')
    else:
        warnings.warn("The validation folder already exists! No validation set created.")

# %% [markdown]
# Create the validation set. We'll take 20 of the 100 pictures for validation:

# %%
make_val_set(PATH, 20)

# %% [markdown]
# Initialize data object

# %%
data = ImageDataBunch.from_folder(PATH, ds_tfms=get_transforms(), size=224)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (147 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# frame video ppt slides,frame video ppt slides,frame video ppt slides,frame video ppt slides,frame video ppt slides
# Path: /fastai/data/FramePresenternSlides;
#
# Valid: LabelList (38 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# frame video ppt slides,frame video ppt slides,frame video ppt slides,frame video ppt slides,frame video ppt slides
# Path: /fastai/data/FramePresenternSlides;
#
# Test: None

# %% [markdown]
# ## Let's see what a frozen ResNet34 can do

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.184559</td>
#       <td>0.534437</td>
#       <td>0.210526</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.800307</td>
#       <td>1.036090</td>
#       <td>0.184211</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.707645</td>
#       <td>0.706429</td>
#       <td>0.131579</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.671348</td>
#       <td>0.449519</td>
#       <td>0.105263</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# The interpretation-thing is awesome!!

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# There are clearly some non Hot or Corn Dog pictures in the dataset! The confusion matrix looks pretty god:

# %%
interp.plot_confusion_matrix(figsize=(4,4), dpi=60)

# %% [markdown]
# ## Let's try to unfreeze:

# %%
learn.unfreeze()

# %% [markdown]
# find a learning rate

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# 10e-4 should be good!

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-6,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.555493</td>
#       <td>0.312324</td>
#       <td>0.078947</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.474465</td>
#       <td>0.219802</td>
#       <td>0.105263</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.383180</td>
#       <td>0.171200</td>
#       <td>0.131579</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.325525</td>
#       <td>0.177092</td>
#       <td>0.131579</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Not really an improvement, but in there are only 20 images in the validation set, so that's ok.

# %% [markdown]
# ## Install chrome-driver if you want to load more than 100 pics

# %%
# !wget https://chromedriver.storage.googleapis.com/2.35/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !mkdir /usr/bin/chromedriver
# !mv chromedriver /usr/bin/chromedriver
# !chown root:root /usr/bin/chromedriver
# !chmod +x /usr/bin/chromedriver
# !curl -sS -o - https://dl-ssl.google.com/linux/linux_signing_key.pub | apt-key add
# !echo "deb [arch=amd64]  http://dl.google.com/linux/chrome/deb/ stable main" >> /etc/apt/sources.list.d/google-chrome.list
# !apt-get -y update
# !apt-get -y install google-chrome-stable
